# %%
import pandas as pd, numpy as np
import seaborn as sns, scipy as sp
import statistics as stats, matplotlib.pyplot as plt

print('imported neccesary libraries.')
# Out:
# imported neccesary libraries.

# %% [markdown]
# ## TRANSFORMING DATASET

# %%
# Extracting Dataset

path = 'youtubers_df.csv'
df =pd.read_csv(path)
df.head()
# Out:
#    Rank       Username           Categories   Suscribers         Country  \
# 0     1        tseries       Música y baile  249500000.0           India
# 1     2        MrBeast   Videojuegos, Humor  183500000.0  Estados Unidos
# 2     3      CoComelon            Educación  165500000.0         Unknown
# 3     4       SETIndia                  NaN  162600000.0           India
# 4     5  KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
#
#         Visits      Likes  Comments  \
# 0      86200.0     2700.0      78.0
# 1  117400000.0  5300000.0   18500.0
# 2    7000000.0    24700.0       0.0
# 3      15600.0      166.0       9.0
# 4    3900000.0    12400.0       0.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# ...

# %% [markdown]
# ## RENAMING COLUMN

# %%
df.rename(columns ={'Suscribers':'Subscribers'}, inplace = True)
df.head
# Out:
# <bound method NDFrame.head of      Rank              Username           Categories  Subscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# ...

# %%
df. shape
# Out:
# (1000, 9)

# %%
df. info
# Out:
# <bound method DataFrame.info of      Rank              Username           Categories  Subscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# ...

# %%
# missing data
df.isnull().sum()
# Out:
# Rank             0
# Username         0
# Categories     306
# Subscribers      0
# Country          0
# Visits           0
# Likes            0
# Comments         0
# Links            0
# dtype: int64

# %%
df.describe()
# Out:
#               Rank   Subscribers        Visits         Likes       Comments
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean    500.500000  2.189440e+07  1.209446e+06  5.363259e+04    1288.768000
# std     288.819436  1.682775e+07  5.229942e+06  2.580457e+05    6778.188308
# min       1.000000  1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%     250.750000  1.380000e+07  3.197500e+04  4.717500e+02       2.000000
# 50%     500.500000  1.675000e+07  1.744500e+05  3.500000e+03      67.000000
# 75%     750.250000  2.370000e+07  8.654750e+05  2.865000e+04     472.000000
# max    1000.000000  2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %%
# missing data
import pandas as pd

#Assuming df is already defined
missing_values = df.isnull(). sum()
print("missing values:")
print(missing_values)

# Correct the typoin column name and fill missing values with the mean
df['Subscribers'].fillna(df['Subscribers'].mean(), inplace = True)

#check missing values after imputation
missing_values_after_imputation = df.isnull().sum()
print("\nMissing values after imputation:")
print(missing_values_after_imputation)
# Out:
# missing values:
# Rank             0
# Username         0
# Categories     306
# Subscribers      0
# Country          0
# Visits           0
# Likes            0
# Comments         0
# Links            0
# dtype: int64
#
# Missing values after imputation:
# Rank             0
# Username         0
# Categories     306
# Subscribers      0
# Country          0
# Visits           0
# Likes            0
# Comments         0
# Links            0
# dtype: int64

# %%
# outliers
sns.boxplot(x=df['Subscribers'])
plt.show()

# %%
#top youtube streamers and top categories

top_Subscribers = df.sort_values(by = 'Subscribers', ascending = False).head(10)
print("\nTop channels by Subscribers")
print(top_Subscribers)
# Out:
# Top channels by Subscribers
#    Rank            Username              Categories  Subscribers  \
# 0     1             tseries          Música y baile  249500000.0
# 1     2             MrBeast      Videojuegos, Humor  183500000.0
# 2     3           CoComelon               Educación  165500000.0
# 3     4            SETIndia                     NaN  162600000.0
# 4     5       KidsDianaShow     Animación, Juguetes  113500000.0
# 5     6           PewDiePie  Películas, Videojuegos  111500000.0
# 6     7  LikeNastyaofficial                Juguetes  107500000.0
# 7     8         VladandNiki     Animación, Juguetes  101400000.0
# 8     9     zeemusiccompany          Música y baile   99700000.0
# 9    10                 WWE             Videojuegos   97200000.0
#
#           Country       Visits      Likes  Comments  \
# 0           India      86200.0     2700.0      78.0
# 1  Estados Unidos  117400000.0  5300000.0   18500.0
# 2         Unknown    7000000.0    24700.0       0.0
# ...

# %%
#streamers audience by country
import pandas as pd
import matplotlib.pyplot as plt

#assuming df and categorial_columns are already defined
categorical_columns = {'Country'}

for column in categorical_columns:
    value_counts = pd.Series(df[column]) .value_counts()
    plt.figure(figsize=(11,6))
    value_counts.plot(kind='bar', color='blue')
    plt.title(f'Subscribers Distribution of {column}')
    plt.xlabel(column.title())
    plt.ylabel('Subscribers')
    plt.xticks(rotation=75)
    plt.show()

# %%
plt.figure(figsize = (11,6))
sns.histplot(df['Subscribers'], bins=20, kde=True)
plt.title('Distribution of Subscribers')
plt.xlabel('Country')
plt.ylabel('Subscribers')
plt.show()

# %%
#above-average
average_suscribers = df['Subscribers'].mean()
average_visits = df['Visits'].mean()
average_likes = df['Likes'].mean()
average_comments = df['Comments'].mean()


 # Filter streamers with above-average performance metrics
above_average_streamers = df[(df['Subscribers'] > average_suscribers) &
                             (df['Visits'] > average_visits) &
                             (df['Likes'] > average_likes) &
                             (df['Comments'] > average_comments)]

# %%
top_channels_subscribers =df.sort_values(by='Subscribers', ascending=False).head(5)
top_channels_subscribers
# Out:
#    Rank       Username           Categories  Subscribers         Country  \
# 0     1        tseries       Música y baile  249500000.0           India
# 1     2        MrBeast   Videojuegos, Humor  183500000.0  Estados Unidos
# 2     3      CoComelon            Educación  165500000.0         Unknown
# 3     4       SETIndia                  NaN  162600000.0           India
# 4     5  KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
#
#         Visits      Likes  Comments  \
# 0      86200.0     2700.0      78.0
# 1  117400000.0  5300000.0   18500.0
# 2    7000000.0    24700.0       0.0
# 3      15600.0      166.0       9.0
# 4    3900000.0    12400.0       0.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# ...

# %%
top_channels_subscribers =df.sort_values(by='Likes',ascending=False).head(5)
top_channels_subscribers
# Out:
#      Rank         Username          Categories  Subscribers         Country  \
# 1       2          MrBeast  Videojuegos, Humor  183500000.0  Estados Unidos
# 136   137         MrBeast2       Vlogs diarios   31300000.0  Estados Unidos
# 153   154        DaFuqBoom    Animación, Humor   29800000.0  Estados Unidos
# 341   342  triggeredinsaan               Humor   20400000.0           India
# 734   735          Mythpat                 NaN   13900000.0           India
#
#           Visits      Likes  Comments  \
# 1    117400000.0  5300000.0   18500.0
# 136   83100000.0  5000000.0   11600.0
# 153   52700000.0  1700000.0   82800.0
# 341   11100000.0  1400000.0   38000.0
# 734   11700000.0  1200000.0   15800.0
#
#                                                  Links
# 1    http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 136  http://youtube.com/channel/UC4-79UOlP48-QNGgCk...
# 153  http://youtube.com/channel/UCsSsgPaZ2GSmO6il8C...
# ...

# %%
top_channels_subscribers =df.sort_values(by='Visits',ascending=False).head(5)
top_channels_subscribers
# Out:
#      Rank               Username          Categories  Subscribers  \
# 1       2                MrBeast  Videojuegos, Humor  183500000.0
# 136   137               MrBeast2       Vlogs diarios   31300000.0
# 153   154              DaFuqBoom    Animación, Humor   29800000.0
# 488   489      BeastPhilanthropy     Comida y bebida   16900000.0
# 288   289  VillageCookingChannel                 NaN   22500000.0
#
#             Country       Visits      Likes  Comments  \
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# 136  Estados Unidos   83100000.0  5000000.0   11600.0
# 153  Estados Unidos   52700000.0  1700000.0   82800.0
# 488  Estados Unidos   21500000.0   952100.0   24000.0
# 288           India   21500000.0   321500.0    5900.0
#
#                                                  Links
# 1    http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 136  http://youtube.com/channel/UC4-79UOlP48-QNGgCk...
# 153  http://youtube.com/channel/UCsSsgPaZ2GSmO6il8C...
# ...

# %%
top_channels_subscribers =df.sort_values(by='Comments',ascending=False).head(5)
top_channels_subscribers
# Out:
#      Rank            Username              Categories  Subscribers  \
# 436   437  BispoBrunoLeonardo          Música y baile   18000000.0
# 153   154           DaFuqBoom        Animación, Humor   29800000.0
# 958   959             dojacat          Música y baile   11900000.0
# 177   178              DanTDM  Animación, Videojuegos   27800000.0
# 341   342     triggeredinsaan                   Humor   20400000.0
#
#             Country      Visits      Likes  Comments  \
# 436          Brasil    762100.0   276400.0  154000.0
# 153  Estados Unidos  52700000.0  1700000.0   82800.0
# 958  Estados Unidos  13600000.0   395300.0   73000.0
# 177  Estados Unidos   3500000.0   285000.0   52500.0
# 341           India  11100000.0  1400000.0   38000.0
#
#                                                  Links
# 436  http://youtube.com/channel/UCVNouUw3d3l5JYVCxh...
# 153  http://youtube.com/channel/UCsSsgPaZ2GSmO6il8C...
# 958  http://youtube.com/channel/UCzpl23pGTHVYqvKsgY...
# ...

# %%
#content recommendations
grouped_by_country = df.groupby('Country').agg(Subscribers=('Subscribers','sum'), Likes=('Likes', 'sum')).reset_index()
print("Total Subscribers and Likes by Country:")
print(grouped_by_country.to_string())
# Out:
# Total Subscribers and Likes by Country:
#            Country   Subscribers       Likes
# 0   Arabia Saudita  7.460000e+07    116100.0
# 1          Argelia  3.150000e+07     28800.0
# 2        Argentina  1.241000e+08    930853.0
# 3       Bangladesh  5.520000e+07      1048.0
# 4           Brasil  1.246900e+09   1729333.0
# 5         Colombia  3.354000e+08    895029.0
# 6          Ecuador  2.680000e+07      4300.0
# 7           Egipto  6.990000e+07      7512.0
# 8      El Salvador  2.190000e+07    707600.0
# 9           España  6.460000e+07    122500.0
# 10  Estados Unidos  6.266600e+09  27481754.0
# 11       Filipinas  2.610000e+08    329029.0
# 12         Francia  8.590000e+07    119037.0
# 13           India  5.823700e+09  12738437.0
# 14       Indonesia  7.525000e+08    741917.0
# 15            Iraq  7.870000e+07    562400.0
# 16           Japón  5.400000e+07     96924.0
# 17        Jordania  1.420000e+07      1900.0
# 18       Marruecos  2.580000e+07       195.0
# ...
